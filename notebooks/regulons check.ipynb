# %%
import os
import anndata
import numpy as np
import pandas as pd
import scanpy as sc
import loompy as lp
from MulticoreTSNE import MulticoreTSNE as TSNE
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import csv
import gzip
import anndata as ad
from pathlib import Path
import glob
from sklearn.preprocessing import StandardScaler


sc.settings.verbosity = 3 # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.set_figure_params(dpi=150, fontsize=10, dpi_save=600)
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.1
# -----
# MulticoreTSNE               NA
# PIL                         9.1.0
# appnope                     0.1.2
# asttokens                   NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# cffi                        1.15.0
# cloudpickle                 2.1.0
# cycler                      0.10.0
# cython_runtime              NA
# cytoolz                     0.11.0
# dask                        2022.9.0
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# entrypoints                 0.4
# executing                   0.8.3
# fsspec                      2022.8.2
# h5py                        3.7.0
# hypergeom_ufunc             NA
# igraph                      0.10.1
# ipykernel                   6.9.1
# ipython_genutils            0.2.0
# ipywidgets                  7.6.5
# jedi                        0.18.1
# jinja2                      3.0.3
# joblib                      1.1.0
# kiwisolver                  1.4.2
# leidenalg                   0.9.0
# llvmlite                    0.38.0
# loompy                      3.0.7
# louvain                     0.8.0
# markupsafe                  2.0.1
# matplotlib                  3.5.2
# mpl_toolkits                NA
# natsort                     8.1.0
# nbinom_ufunc                NA
# numba                       0.55.1
# numexpr                     2.8.3
# numpy                       1.21.5
# numpy_groupies              0.9.19
# packaging                   21.3
# pandas                      1.4.2
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# prompt_toolkit              3.0.20
# psutil                      5.9.1
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     9.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pyexpat                     NA
# pygments                    2.11.2
# pyparsing                   3.0.4
# pytz                        2022.1
# ruamel                      NA
# scipy                       1.8.0
# seaborn                     0.11.2
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.0.2
# stack_data                  0.2.0
# statsmodels                 0.13.2
# tblib                       1.7.0
# texttable                   1.6.4
# threadpoolctl               3.1.0
# tlz                         0.11.0
# toolz                       0.12.0
# tornado                     6.1
# traitlets                   5.1.1
# typing_extensions           NA
# wcwidth                     0.2.5
# yaml                        6.0
# zmq                         22.3.0
# -----
# IPython             8.2.0
# jupyter_client      7.2.2
# jupyter_core        4.9.2
# notebook            6.4.8
# -----
# Python 3.9.7 (default, Sep 16 2021, 08:50:36) [Clang 10.0.0 ]
# macOS-10.16-x86_64-i386-64bit
# -----
# Session information updated at 2023-07-17 16:22

# %%
pwd
# Out:
# '/Users/lidiayung/github/2022PhD/notebooks'

# %%
regulons = pd.read_csv('/Users/lidiayung/project/resource/regulons.csv', sep=';')

# %%
string_list = []

# Iterate over the columns
for column in regulons.columns:
    # Iterate over the rows
    for value in regulons[column]:
        # Check if the value is a string
        if isinstance(value, str):
            # Append the string to the list
            string_list.append(value)

# %%
string_list
# Out:
# ['SOX10',
#  'SREBF1',
#  'FOS',
#  'LEF1',
#  'SMAD6',
#  'ERG',
#  'BCL11B',
#  'IRF4',
#  'ETS1',
#  'ELF1',
#  'REL',
#  'TFEC',
#  'IRF8',
#  'MAF',
#  'TLX2',
#  'MLXIPI',
#  'NFIC',
#  'EGR1',
#  'E2F2',
#  'FOXM1',
#  'E2F7',
#  'SOX8',
#  'SOX11',
#  'SOX5',
#  'SOX2',
#  'RBBP5',
#  'NR112',
#  'CEBPG',
#  'BARX2',
#  'CTCF',
#  'MYCN',
#  'KLF11',
#  'RUNX1',
#  'CREM',
#  'RUNX3',
#  'ELF4',
#  'IKZF1',
#  'NFATC2',
#  'PRDM1',
#  'JUN',
#  'TCF7L1',
#  'SoX9',
#  'PRRX1',
#  'PRRX1',
#  'HES4',
#  'SREBF2',
#  'MAZ',
#  'LHX5',
#  'TCF4',
#  'ASCL1',
#  'SOX11',
#  'SOX4',
#  'E2F2',
#  'ZEB1',
#  'HES1',
#  'GATA6',
#  'NR1D1',
#  'FOXC1',
#  'CREB5',
#  'FOX01',
#  'SHOX2',
#  'AR',
#  'E2F7',
#  'MYBL1',
#  'E2F8',
#  'MYBL2',
#  'BRCA1',
#  'E2F2',
#  'PITX2',
#  'RFX4',
#  'SREBF1',
#  'DDIT3',
#  'STAT3',
#  'EPAS1',
#  'SOX2',
#  'SOX5',
#  'SOX10',
#  'SOX4',
#  'ELF2',
#  'PBX3',
#  'ZEB1',
#  'TWIST1',
#  'HMGA2',
#  'ERG',
#  'FOXP1',
#  'JDP2',
#  'SPI1',
#  'MEF2C',
#  'TFEC',
#  'THAP1',
#  'DUXA',
#  'TBX20',
#  'HNF4A',
#  'NFIC',
#  'TCF7L2',
#  'TCF7L1',
#  'NFATC4',
#  'TEAD',
#  'TEAD',
#  'BCL6',
#  'ESRRG',
#  'BHLHE22',
#  'SOX5',
#  'ZMAT4',
#  'CUX2',
#  'ARNT2',
#  'IRF2',
#  'SREBF1',
#  'TE',
#  'CREBL2',
#  'IKZF',
#  'SPI1',
#  'ETS2',
#  'FLI1',
#  'FOS',
#  'REL',
#  'REL',
#  'ZNF569',
#  'OLIG1',
#  'BCL11A',
#  'CUX2',
#  'LHX6',
#  'STAT4',
#  'ZMAT4',
#  'TFDP1',
#  'MYBL1',
#  'E2F1',
#  'E2F2',
#  'MYBL2',
#  'ETS1',
#  'ZNF91',
#  'SOX5',
#  'ZEB1',
#  'FOXG1',
#  'OLIG2',
#  'FOXS1',
#  'PRDM16',
#  'EMX2',
#  'STAT3',
#  'PRRX1',
#  'STAT1',
#  'TEAD4',
#  'ATF3',
#  'FOSB',
#  'MEF2C',
#  'ELF1',
#  'MITF',
#  'IKZF1',
#  'IRF8',
#  'SPI1',
#  'ZNF710',
#  'STAT2',
#  'SOX4',
#  'CREB5',
#  'OLIG1',
#  'BHLHE41',
#  'IRF8',
#  'ETS2',
#  'JDP2',
#  'SPI1',
#  'IRF5',
#  'ZNF572',
#  'HOXA13',
#  'ZBTB26',
#  'TBX15',
#  'FOXC1',
#  'FOXC2',
#  'ELF1',
#  'IRF2',
#  'ONECUT2',
#  'SOX11',
#  'SOX6',
#  'SOX5',
#  'E2F3',
#  'CUX2',
#  'MYC',
#  'PBX3',
#  'ZEB1',
#  'FEV',
#  'ARNTL',
#  'CREB5',
#  'POU3F4',
#  'AR',
#  'ETV2',
#  'IRF6',
#  'MSC',
#  'POU2F2',
#  'FOXN3',
#  'IRF8',
#  'ELK3',
#  'ELF1',
#  'FL11',
#  'STAT3',
#  'CEBPB',
#  'FOSL2',
#  'IRF7',
#  'RBBP5',
#  'CEBPG',
#  'ATF4',
#  'MITF',
#  'CREB5',
#  'BACH2',
#  'FOXN2',
#  'FOXD4L6',
#  'ZMAT4',
#  'FOXP3',
#  'ARX',
#  'NR3C2',
#  'SOX4',
#  'LHX1',
#  'RORB',
#  'SOX2',
#  'ZBTB16',
#  'TCF7L1',
#  'RFX4',
#  'TCF4',
#  'RORA',
#  'IKZF3',
#  'RFXAP',
#  'ZNF607',
#  '50X21',
#  'FOX01',
#  'EPAS1',
#  'TPI1',
#  'TBX15',
#  'LEF1',
#  'TAL',
#  'CEBPB',
#  'FLI1',
#  'IRF8',
#  'SPI1',
#  'JUN',
#  'FOSL2',
#  'IRF1',
#  'LHX1',
#  'CUX2',
#  'CELF5',
#  'NEUROD2',
#  'MAZ',
#  'E2F7',
#  'BRCA1',
#  'E2F1',
#  'SOX10',
#  'ARNT2',
#  'MYCN',
#  'SOX11',
#  'SOX4',
#  'E2F3',
#  'SOX6',
#  'SREBF2']

# %%
# create an empty dictionary to store string counts
string_count = {}

# loop through the data and add each string to the dictionary
for string in string_list:
    count = string_count.get(string, 0)
    string_count[string] = count + 1

# create a new dictionary to store only the repeated strings
repeated_strings = {}
for key, value in string_count.items():
    if value > 1:
        repeated_strings[key] = value

# %%
import operator

# Sort the repeated_strings dictionary by value (frequency) in descending order
sorted_items = sorted(repeated_strings.items(), key=operator.itemgetter(1), reverse=True)

# Print the table
print("Item\tFrequency")
for key, value in sorted_items:
    print(f"{key}\t{value}")
# Out:
# Item	Frequency
# IRF8	5
# SOX5	5
# SOX4	5
# SPI1	5
# ELF1	4
# E2F2	4
# SOX11	4
# ZEB1	4
# CREB5	4
# CUX2	4
# SOX10	3
# SREBF1	3
# REL	3
# E2F7	3
# SOX2	3
# TCF7L1	3
# PRRX1	3
# STAT3	3
# ZMAT4	3
# FOS	2
# LEF1	2
# ERG	2
# ETS1	2
# TFEC	2
# NFIC	2
# RBBP5	2
# CEBPG	2
# MYCN	2
# IKZF1	2
# JUN	2
# SREBF2	2
# MAZ	2
# TCF4	2
# FOXC1	2
# FOX01	2
# AR	2
# MYBL1	2
# MYBL2	2
# BRCA1	2
# RFX4	2
# EPAS1	2
# PBX3	2
# JDP2	2
# MEF2C	2
# TEAD	2
# ARNT2	2
# IRF2	2
# ETS2	2
# FLI1	2
# OLIG1	2
# E2F1	2
# MITF	2
# TBX15	2
# SOX6	2
# E2F3	2
# CEBPB	2
# FOSL2	2
# LHX1	2

# %%
genes = pd.read_csv('/Users/lidiayung/project/resource/genes.csv', sep=';')

# %%
genes
# Out:
#        SF2777         SF2990      SF3076                 SF9358      SF11916  \
# 0      THSD7A       ADAMTS18        KAZN                  NXPH1       THEMIS
# 1        PID1          NLGN1       NDRG1                 RBFOX1         CCL5
# 2      LRRTM4           DLG2     ANGPTL4                  ERBB4        SKAP1
# 3      KCNIP4           UGT8       VEGFA                GALNTL6       PLXDC2
# 4       KCNB2     AC093590.1      DNAH11                   KAZN      EPB41L3
# 5        RYR2      LINC00463         JUN                  SLIT2       ADAM28
# 6       FSTL4            VWE       GLIS3                 CLSTN2        VSIG4
# 7       ADARB         ADGRF5  RNF219-AS1                  MYTIL     TNFRSF1B
# 8       MYT1L        ADAMTS2      ADGRV1                 KCNMA1     C10orf11
# 9        NEBL         PDGFRB         KCP            IQCJ-SCHIP1        PEX5L
# 10      CADPS         COL1A2       CPLX1                 HS3ST4         ST18
# 11       EGFR          TRPC4       TSHZ2                 SPOCK1        CNTN2
# 12  AC079135.          AGBL4      AKNAD1                  TMTC2         MYRF
# 13     ADGRVI        PCDH11X        DSEL                 MT-CO1        ZMAT4
# 14      TIMP3          SYNPR       TENM3                    OS9      SLC35F3
# 15      NAMPT          FSTL4  AC007682.1                 COL1A1        DPP10
# 16       ACTN         GABRG3       LRRN1                 COL3A1       RBFOX1
# 17        MET         ADARB2      RNF220                    DCN         RYR2
# 18      DANT2           GPR1        ST18                 HSPA1B        PPM1E
# 19        CD6        COL11A1       EEPD1                 SNHG25      CNTNAP2
# 20    COLEC12        SLFN121         HK2                  MEPCE  IQCJ-SCHIP1
# 21       NCF1          SKAP1       PLIN2                 CAPNS1        BRIP1
# 22       PDK4         HILPDA      SFMBT2                  ATAD2          DTL
# 23       CD83          TRPM3      TBXAS1                  SKAP1        XRCC2
# 24     SPOCK3         KIF18B      PLXDC2                  DOCK8         BMP2
# 25     RNF220          TOP2A        CD44  RP11-742B18.1742B18.1         RGS6
# 26       HMMR         IGFBP2         EMB                  FKBP5        CPNE4
# 27    C2orf48         TMEM71       SKAP1                  LRRK2        TACR1
# 28       APOI     AC079584.2       PLCG2                    REL         RORB
# 29     AKAP12        SHROOM3       CENPF                SLC11A1        CPNE5
# 30        NaN          ADCY8      KCNIP4                    NaN        KCNN3
# 31        NaN          PAMR1    TNFRSF25                    NaN   AC092684.1
# 32        NaN  RP11-627D16.1        RYR2                    NaN         LHFP
# 33        NaN   RP11-302M6.4    CACNA2D3                    NaN       COL1A2
# 34        NaN   RP4-543113.1      ADARB2                    NaN         SVIL
# 35        NaN          MEF2C       ABCB1                    NaN        FGFR1
# 36        NaN          MEF2A         VWE                    NaN       SEC61G
# 37        NaN      LINC01094        DLC1                    NaN         PDK1
# 38        NaN   RP11-142C4.6        EBF1                    NaN        EGLN3
# 39        NaN          CD109      PDGFRB                    NaN        VEGFA
# 40        NaN           CREM         NaN                    NaN          NaN
# 41        NaN           RGS1         NaN                    NaN          NaN
# 42        NaN            NaN         NaN                    NaN          NaN
#
#        SF11082        SF9798         SF3391
# 0          TOX        GABBR2         STXBP6
# 1          ALK         CELF4          KANK4
# 2     C10orf90          PTPR      LINC00844
# 3        GPR39        ADARB2   RP4-630C24.3
# 4        TRPM3        SEMA3E        SLC5A11
# 5         CD44         CADPS      LINC01378
# 6         SDK1         POSTN          ITGA8
# 7       PRUNE2         UNC5D           TLL1
# 8         TNIK        FAM83D          ARRB1
# 9       3020.1        KIF18B          LRRK1
# 10       MYTIL          POLO   CTC-535M15.2
# 11       KCNH7         VEGFA          CALB2
# 12       TENM4         GLRA3            KIT
# 13        GRIA         BMPER        GALNTL6
# 14        NRG3  RP4-668E10.4           GAD2
# 15      SHISA9        LHFPL3          LUZP2
# 16       ADCYE          FLT1       TMEM132C
# 17        SYN3        ADGRL4        AFAP1L2
# 18       TOP2A         ENPEP        SLFN121
# 19       MKI67        PDGFRB        TPD52L1
# 20       CENPF        COL6A2       SLC39A12
# 21      LHFPL3         SPON1           DIO2
# 22       FGF12       LRRC16A         BTBD11
# 23      ST6GAL    ST6GALNAC5             XG
# 24      TBXASI         SKAP1           GYG2
# 25        SRGN         STAT4         COL6A3
# 26     ANGPTL4     LINC01608           RFC3
# 27       TUBE1       TCP11L2            DTL
# 28       HSPA6          LDB3          KIF2C
# 29      HSPAIA           A2M          CDCA2
# 30     TMEM204         FCGBP           ATF5
# 31       PTPRB         EEPD1  CTD-2231H16.1
# 32      ADGRL4         ABCA1          FCGBP
# 33       PTPRG          SRGN  RP11-202G18.1
# 34        EDN3         HCLS1       C22orf34
# 35       HPSE2           NaN         TWIST2
# 36       HNF4G           NaN         HSPA1A
# 37  AC005537.2           NaN  RP11-154H12.3
# 38       SAMD3           NaN         TUBA1C
# 39       HMCN1           NaN            F12
# 40        VCAN           NaN            NaN
# 41       PRKG1           NaN            NaN
# 42        IGF1           NaN            NaN

# %%
string_list = []

# Iterate over the columns
for column in genes.columns:
    # Iterate over the rows
    for value in genes[column]:
        # Check if the value is a string
        if isinstance(value, str):
            # Append the string to the list
            string_list.append(value)

# %%
# create an empty dictionary to store string counts
string_count = {}

# loop through the data and add each string to the dictionary
for string in string_list:
    count = string_count.get(string, 0)
    string_count[string] = count + 1

# create a new dictionary to store only the repeated strings
repeated_strings = {}
for key, value in string_count.items():
    if value > 1:
        repeated_strings[key] = value

# %%
import operator

# Sort the repeated_strings dictionary by value (frequency) in descending order
sorted_items = sorted(repeated_strings.items(), key=operator.itemgetter(1), reverse=True)

# Print the table
print("Item\tFrequency")
for key, value in sorted_items:
    print(f"{key}\t{value}")
# Out:
# Item	Frequency
# SKAP1	5
# RYR2	3
# PDGFRB	3
# ADARB2	3
# VEGFA	3
# KCNIP4	2
# FSTL4	2
# CADPS	2
# RNF220	2
# VWE	2
# COL1A2	2
# SLFN121	2
# TRPM3	2
# KIF18B	2
# TOP2A	2
# KAZN	2
# ANGPTL4	2
# ST18	2
# EEPD1	2
# PLXDC2	2
# CD44	2
# CENPF	2
# RBFOX1	2
# GALNTL6	2
# MYTIL	2
# IQCJ-SCHIP1	2
# DTL	2
# LHFPL3	2
# SRGN	2
# ADGRL4	2
# FCGBP	2
