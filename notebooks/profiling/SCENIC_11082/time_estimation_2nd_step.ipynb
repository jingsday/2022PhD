# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import loompy as lp
from MulticoreTSNE import MulticoreTSNE as TSNE
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import csv
import gzip
import anndata as ad
from pathlib import Path
import glob
import time

sc.settings.verbosity = 3 # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.set_figure_params(dpi=150, fontsize=10, dpi_save=600)
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.3
# -----
# MulticoreTSNE               NA
# PIL                         9.4.0
# asttokens                   NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# bottleneck                  1.3.5
# cffi                        1.15.1
# cloudpickle                 2.2.1
# colorama                    0.4.6
# comm                        0.1.2
# cycler                      0.10.0
# cython_runtime              NA
# cytoolz                     0.12.0
# dask                        2023.4.1
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# executing                   0.8.3
# h5py                        3.7.0
# hypergeom_ufunc             NA
# igraph                      0.10.2
# importlib_resources         NA
# invgauss_ufunc              NA
# ipykernel                   6.19.2
# ipython_genutils            0.2.0
# ipywidgets                  8.0.4
# jedi                        0.18.1
# jinja2                      3.1.2
# joblib                      1.1.1
# jupyter_server              1.23.4
# kiwisolver                  1.4.4
# leidenalg                   0.9.1
# llvmlite                    0.40.0
# loompy                      3.0.7
# louvain                     0.8.0
# markupsafe                  2.1.1
# matplotlib                  3.7.1
# mpl_toolkits                NA
# natsort                     8.2.0
# nbinom_ufunc                NA
# ncf_ufunc                   NA
# nct_ufunc                   NA
# ncx2_ufunc                  NA
# numba                       0.57.0
# numexpr                     2.8.4
# numpy                       1.21.5
# numpy_groupies              0.9.20
# packaging                   23.0
# pandas                      1.5.3
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                2.5.2
# plotly                      5.9.0
# prompt_toolkit              3.0.36
# psutil                      5.9.0
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pyarrow                     10.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.15.1
# pyparsing                   3.0.9
# pytz                        2022.7
# scipy                       1.10.1
# seaborn                     0.12.2
# session_info                1.0.0
# setuptools                  66.0.0
# six                         1.16.0
# skewnorm_ufunc              NA
# sklearn                     1.2.2
# sphinxcontrib               NA
# stack_data                  0.2.0
# statsmodels                 0.13.5
# tblib                       1.7.0
# texttable                   1.6.6
# threadpoolctl               2.2.0
# tlz                         0.12.0
# toolz                       0.12.0
# tornado                     6.2
# traitlets                   5.7.1
# typing_extensions           NA
# wcwidth                     0.2.5
# yaml                        6.0
# zipp                        NA
# zmq                         25.0.2
# zoneinfo                    NA
# zope                        NA
# -----
# IPython             8.12.0
# jupyter_client      8.1.0
# jupyter_core        5.3.0
# jupyterlab          3.5.3
# notebook            6.5.4
# -----
# Python 3.9.16 (main, Mar  8 2023, 14:00:05) [GCC 11.2.0]
# Linux-6.2.0-26-generic-x86_64-with-glibc2.35
# -----
# Session information updated at 2023-08-23 22:48
# /home/jing/anaconda3/lib/python3.9/site-packages/loompy/bus_file.py:68: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_to_dna(twobit: int, size: int) -> str:
# /home/jing/anaconda3/lib/python3.9/site-packages/loompy/bus_file.py:85: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def dna_to_twobit(dna: str) -> int:
# /home/jing/anaconda3/lib/python3.9/site-packages/loompy/bus_file.py:102: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_1hamming(twobit: int, size: int) -> List[int]:

# %%
def sce(sample):

    #set corresponding folders which the results of each specimen are written to
  

    f_db_glob = "/home/jing/scratch/resource/*feather"
    f_db_names = ' '.join( glob.glob(f_db_glob) )
    
    # motif databases
    f_motif_path = "/home/jing/scratch/resource/motifs-v9-nr.hgnc-m0.001-o0.0.tbl"
    f_tfs = "/home/jing/scratch/resource/allTFs_hg38.txt"
    
    output_folder = "/home/jing/projects/samples/"
    output_path = os.path.join(output_folder, sample)
    print(output_path)
    os.chdir(output_path)
    
    f_loom_path_scenic = f"{output_path}/{sample}singlesample.loom"

    print(f_loom_path_scenic)
    os.chdir(output_path)

    # path to  loom file

    adata= sc.read_loom(f_loom_path_scenic)
    print(adata)
    
   
    f_pyscenic_output = f"{output_path}/{sample}singletumorscenic.loom"
    f_final_loom = f"{output_path}/{sample}mergedscenic_integrated-output.loom"
    
    
    
    #II
    # !pyscenic ctx adj.csv \
        {f_db_names} \
        --annotations_fname {f_motif_path} \
        --expression_mtx_fname {f_loom_path_scenic} \
        --output reg.csv \
        --mask_dropouts \
        --num_workers 12

# %%
sce('SF11082')
# Out:
# /home/jing/projects/samples/SF3073
# /home/jing/projects/samples/SF3073/SF3073singlesample.loom
# AnnData object with n_obs × n_vars = 608 × 33694
#     obs: 'nGene', 'nUMI'
# /home/jing/anaconda3/lib/python3.9/site-packages/loompy/bus_file.py:68: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_to_dna(twobit: int, size: int) -> str:
# /home/jing/anaconda3/lib/python3.9/site-packages/loompy/bus_file.py:85: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def dna_to_twobit(dna: str) -> int:
# /home/jing/anaconda3/lib/python3.9/site-packages/loompy/bus_file.py:102: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_1hamming(twobit: int, size: int) -> List[int]:
#
# 2023-08-23 22:49:01,475 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2023-08-23 22:49:01,630 - pyscenic.cli.pyscenic - INFO - Loading gene signatures.
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []
#
# 2023-08-23 22:49:06,119 - pyscenic.cli.pyscenic - INFO - Calculating cellular enrichment.
#
# 2023-08-23 22:49:09,956 - pyscenic.cli.pyscenic - INFO - Writing results to file.
# /home/jing/anaconda3/lib/python3.9/site-packages/pyscenic/cli/utils.py:347: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, threshold in auc_thresholds.iteritems()
